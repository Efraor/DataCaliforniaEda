# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(style="whitegrid", palette="muted")
print(pd.__version__)
# Out:
# 2.3.3

# %%
df = pd.read_csv("../data/raw/housing.csv")

df.head() #Muestra por defecto las primeras 5 filas del DataFrame.
#df.info() #Ayuda a detectar: Si hay valores nulos, tipos de datos son correctos, etc..
df.describe(include="all") # calcula estadísticas descriptivas para las columnas numéricas
df.shape #Devuelve una tupla: (n_filas, n_columnas).
df.columns #Muestra las columnas
df.isna().sum() #Muestra la cantidad de valores nulos
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# # Dia 2

# %%
df.dtypes

numeric_cols = df.select_dtypes(include= ['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

print("columnas numericas:", list(numeric_cols))
print("columnas categoricas:", list(categorical_cols))

df['median_house_value'].hist(bins=30)
plt.title('Distribucion de median_house_value')
plt.xlabel('media_house_value')
plt.ylabel('frecuencia')
plt.show()
# Out:
# columnas numericas: ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']
# columnas categoricas: ['ocean_proximity']
